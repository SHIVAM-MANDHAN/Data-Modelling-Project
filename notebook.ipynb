# %% [markdown]
# # DATA MODEL - GOAL

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import psycopg2
import numpy as np

# %% [markdown]
# # DATA COLLECTION

# %%
accounts = pd.read_csv("Wealth-AccountData.csv")

# %%
countries = pd.read_csv("Wealth-AccountsCountry.csv")

# %%
series = pd.read_csv("Wealth-AccountSeries.csv")

# %% [markdown]
# # DATA CLEANING

# %%
accounts.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
accounts.shape
# Out:
# (7592, 28)

# %%
# Selecting relevant columns
accounts = accounts[['Country Name', 'Country Code', 'Series Name', 'Series Code', '2018 [YR2018]']]

# %%
accounts.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '2018 [YR2018]'],
#       dtype='object')

# %%
accounts.columns = ['Country Name', 'Country Code', 'Series Name', 'Series Code', 'YR2018']

# %%
accounts.head()
# Out:
#   Country Name Country Code
# 0      Albania          ALB  \
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code    YR2018
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO  8.12E+10
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC  28333.68
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC  3312.927
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC  19245.19
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC  4161.137

# %%
# Handling missing values
missing_rows = accounts[accounts.YR2018==".."]
missing_rows
# Out:
#             Country Name Country Code
# 546               Belize          BLZ  \
# 561               Belize          BLZ
# 910         Burkina Faso          BFA
# 925         Burkina Faso          BFA
# 962              Burundi          BDI
# ...                  ...          ...
# 6697          The Gambia          GMB
# 6994              Uganda          UGA
# 7009              Uganda          UGA
# 7410  West Bank and Gaza          PSE
# 7425  West Bank and Gaza          PSE
#
#                                             Series Name     Series Code YR2018
# 546   Natural capital per capita, nonrenewable asset...  NW.NCA.SAGA.PC     ..
# 561   Natural capital, nonrenewable assets: gas (con...  NW.NCA.SAGA.TO     ..
# 910   Natural capital per capita, nonrenewable asset...  NW.NCA.SAGA.PC     ..
# 925   Natural capital, nonrenewable assets: gas (con...  NW.NCA.SAGA.TO     ..
# 962   Natural capital per capita, nonrenewable asset...  NW.NCA.SAGA.PC     ..
# ...                                                 ...             ...    ...
# 6697  Natural capital, nonrenewable assets: gas (con...  NW.NCA.SAGA.TO     ..
# 6994  Natural capital per capita, nonrenewable asset...  NW.NCA.SAGA.PC     ..
# 7009  Natural capital, nonrenewable assets: gas (con...  NW.NCA.SAGA.TO     ..
# 7410  Natural capital per capita, nonrenewable asset...  NW.NCA.SAGA.PC     ..
# 7425  Natural capital, nonrenewable assets: gas (con...  NW.NCA.SAGA.TO     ..
#
# [74 rows x 5 columns]

# %%
accounts.drop(missing_rows.index, inplace=True)

# %%
# Changing data type
accounts.YR2018 = pd.to_numeric(accounts.YR2018)

# %%
accounts.duplicated().sum()
# Out:
# 0

# %%
accounts.isna().sum()
# Out:
# Country Name    0
# Country Code    0
# Series Name     0
# Series Code     0
# YR2018          0
# dtype: int64

# %%
countries.columns
# Out:
# Index(['Code', 'Long Name', 'Income Group', 'Region', 'Lending category',
#        'Other groups', 'Currency Unit', 'Latest population census',
#        'Latest household survey', 'Special Notes',
#        'National accounts base year', 'National accounts reference year',
#        'System of National Accounts', 'SNA price valuation',
#        'Alternative conversion factor', 'PPP survey years',
#        'Balance of Payments Manual in use', 'External debt Reporting status',
#        'System of trade', 'Government Accounting concept',
#        'IMF data dissemination standard',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data', '2-alpha code', 'WB-2 code',
#        'Table Name', 'Short Name'],
#       dtype='object')

# %%
# Selecting relevant columns
countries = countries[['Code', 'Long Name', 'Income Group', 'Region']]

# %%
countries.shape
# Out:
# (7597, 4)

# %%
# Handling diplicate values
countries.duplicated().sum()
# Out:
# 7304

# %%
countries.drop_duplicates(inplace=True)

# %%
countries.duplicated().sum()
# Out:
# 0

# %%
# Handling NA values
countries.isna().sum()
# Out:
# Code              3
# Long Name         1
# Income Group      2
# Region          147
# dtype: int64

# %%
countries.Region.fillna("not available", inplace=True)

# %%
countries.isna().sum()
# Out:
# Code            3
# Long Name       1
# Income Group    2
# Region          0
# dtype: int64

# %%
countries.dropna(inplace=True)

# %%
countries.isna().sum()
# Out:
# Code            0
# Long Name       0
# Income Group    0
# Region          0
# dtype: int64

# %%
countries.Code.duplicated().sum()
# Out:
# 143

# %%
countries.drop_duplicates(subset=['Code'], inplace=True)

# %%
countries.Code.duplicated().sum()
# Out:
# 0

# %%
series.columns
# Out:
# Index(['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
#        'Unit of measure', 'Periodicity', 'Reference period',
#        'Statistical concept and methodology', 'Previous Indicator Code',
#        'Previous Indicator Name'],
#       dtype='object')

# %%
# Selecting relevant columns
series = series[['Code', 'Indicator Name']]

# %%
series.head()
# Out:
#              Code                                     Indicator Name
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...

# %%
series.duplicated().sum()
# Out:
# 0

# %%
series.Code.duplicated().sum()
# Out:
# 0

# %%
series.isna().sum()
# Out:
# Code              0
# Indicator Name    0
# dtype: int64

# %% [markdown]
# # SETTING UP NEW DATABASE

# %%
# Creating a connection to the database
try:
    conn = psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=Shivam@123456")
    print("connected")
except psycopg2.Error as e:
    print(e)

# %%
# Setting up a cursor (to execute queries)
try:
    cur = conn.cursor()
    print("cursor created")
except psycopg2.Error as e:
    print(e)
    
conn.set_session(autocommit=True)

# %%
# Setting up autocommit
try:
    conn.set_session(autocommit=True)
    print("autocommit done")
except psycopg2.Error as e:
    print(e)

# %%
# Creating new database
query2 = "create database wealthdb"
try:
    cur.execute(query)
    print("db created")
except psycopg2.Error as e:
    print(e)

# %%
#closing connection with existing database
try:
    conn.close()
    print("connection closed")
except psycopg2.Error as e:
    print(e)

# %% [markdown]
# # WORKING ON NEW DATABASE

# %%
# making connection with newly created wealthdb
try:
    conn = psycopg2.connect("host=127.0.0.1 dbname=wealthdb user=postgres password=Shivam@123456")
    print("connected")
except psycopg2.Error as e:
    print(e)
# Out:
# connected

# %%
# adding cursor and autocommit
try:
    cur = conn.cursor()
    print("cursor created")
except psycopg2.Error as e:
    print(e)
    
conn.set_session(autocommit=True)
# Out:
# cursor created

# %%
# creating a table
query1 = "drop table countries"
query2 = "create table countries (country_code varchar primary key, country_name varchar, \
        income_group varchar, region varchar)"

try:
    cur.execute(query1)
    cur.execute(query2)
except psycopg2.Error as e:
    print(e)

# %%
# Inserting data into table
query = '''
    INSERT INTO countries (country_code, country_name, income_group, region)
    VALUES (%s, %s, %s, %s)
    '''

for i in range(len(countries)):
    row = countries.iloc[i]
    
    try:
        cur.execute(query, (row['Code'], row['Long Name'], row['Income Group'], row['Region']))
    except psycopg2.Error as e:
        print(e)

# %%
# Displaying table content
query = "select * from countries"

try:
    cur.execute(query)
except psycopg2.Error as e:
    print(e)
    
rows = cur.fetchall()
for i in rows:
    print(i)
# Out:
# ('ALB', 'Republic of Albania', 'Upper middle income', 'Europe & Central Asia')
# ('ARG', 'Argentine Republic', 'Upper middle income', 'Latin America & Caribbean')
# ('ARM', 'Republic of Armenia', 'Upper middle income', 'Europe & Central Asia')
# ('AUS', 'Commonwealth of Australia', 'High income', 'East Asia & Pacific')
# ('AUT', 'Republic of Austria', 'High income', 'Europe & Central Asia')
# ('AZE', 'Republic of Azerbaijan', 'Upper middle income', 'Europe & Central Asia')
# ('BHR', 'Kingdom of Bahrain', 'High income', 'Middle East & North Africa')
# ('BGD', "People's Republic of Bangladesh", 'Lower middle income', 'South Asia')
# ('BLR', 'Republic of Belarus', 'Upper middle income', 'Europe & Central Asia')
# ('BEL', 'Kingdom of Belgium', 'High income', 'Europe & Central Asia')
# ('BLZ', 'Belize', 'Lower middle income', 'Latin America & Caribbean')
# ('BEN', 'Republic of Benin', 'Lower middle income', 'Sub-Saharan Africa')
# ('BOL', 'Plurinational State of Bolivia', 'Lower middle income', 'Latin America & Caribbean')
# ('BIH', 'Bosnia and Herzegovina', 'Upper middle income', 'Europe & Central Asia')
# ('BWA', 'Republic of Botswana', 'Upper middle income', 'Sub-Saharan Africa')
# ('BRA', 'Federative Republic of Brazil', 'Upper middle income', 'Latin America & Caribbean')
# ('BGR', 'Republic of Bulgaria', 'Upper middle income', 'Europe & Central Asia')
# ('BFA', 'Burkina Faso', 'Low income', 'Sub-Saharan Africa')
# ('BDI', 'Republic of Burundi', 'Low income', 'Sub-Saharan Africa')
# ('KHM', 'Kingdom of Cambodia', 'Lower middle income', 'East Asia & Pacific')
# ('CMR', 'Republic of Cameroon', 'Lower middle income', 'Sub-Saharan Africa')
# ('CAN', 'Canada', 'High income', 'North America')
# ('CAF', 'Central African Republic', 'Low income', 'Sub-Saharan Africa')
# ('TCD', 'Republic of Chad', 'Low income', 'Sub-Saharan Africa')
# ('CHL', 'Republic of Chile', 'High income', 'Latin America & Caribbean')
# ('CHN', "People's Republic of China", 'Upper middle income', 'East Asia & Pacific')
# ('COL', 'Republic of Colombia', 'Upper middle income', 'Latin America & Caribbean')
# ('COM', 'Union of the Comoros', 'Lower middle income', 'Sub-Saharan Africa')
# ('COG', 'Republic of Congo', 'Lower middle income', 'Sub-Saharan Africa')
# ('CRI', 'Republic of Costa Rica', 'Upper middle income', 'Latin America & Caribbean')
# ('CIV', "Republic of Côte d'Ivoire", 'Lower middle income', 'Sub-Saharan Africa')
# ('HRV', 'Republic of Croatia', 'High income', 'Europe & Central Asia')
# ('CZE', 'Czech Republic', 'High income', 'Europe & Central Asia')
# ('COD', 'Democratic Republic of the Congo', 'Low income', 'Sub-Saharan Africa')
# ('DNK', 'Kingdom of Denmark', 'High income', 'Europe & Central Asia')
# ('DJI', 'Republic of Djibouti', 'Lower middle income', 'Middle East & North Africa')
# ('DOM', 'Dominican Republic', 'Upper middle income', 'Latin America & Caribbean')
# ('ECU', 'Republic of Ecuador', 'Upper middle income', 'Latin America & Caribbean')
# ('EGY', 'Arab Republic of Egypt', 'Lower middle income', 'Middle East & North Africa')
# ('SLV', 'Republic of El Salvador', 'Lower middle income', 'Latin America & Caribbean')
# ('EST', 'Republic of Estonia', 'High income', 'Europe & Central Asia')
# ('SWZ', 'Kingdom of Eswatini', 'Lower middle income', 'Sub-Saharan Africa')
# ('ETH', 'Federal Democratic Republic of Ethiopia', 'Low income', 'Sub-Saharan Africa')
# ('FIN', 'Republic of Finland', 'High income', 'Europe & Central Asia')
# ('FRA', 'French Republic', 'High income', 'Europe & Central Asia')
# ('GAB', 'Gabonese Republic', 'Upper middle income', 'Sub-Saharan Africa')
# ('GEO', 'Georgia', 'Upper middle income', 'Europe & Central Asia')
# ('DEU', 'Federal Republic of Germany', 'High income', 'Europe & Central Asia')
# ('GHA', 'Republic of Ghana', 'Lower middle income', 'Sub-Saharan Africa')
# ('GRC', 'Hellenic Republic', 'High income', 'Europe & Central Asia')
# ('GTM', 'Republic of Guatemala', 'Upper middle income', 'Latin America & Caribbean')
# ('GIN', 'Republic of Guinea', 'Low income', 'Sub-Saharan Africa')
# ('GUY', 'Co-operative Republic of Guyana', 'Upper middle income', 'Latin America & Caribbean')
# ('HTI', 'Republic of Haiti', 'Lower middle income', 'Latin America & Caribbean')
# ('HND', 'Republic of Honduras', 'Lower middle income', 'Latin America & Caribbean')
# ('HUN', 'Hungary', 'High income', 'Europe & Central Asia')
# ('ISL', 'Republic of Iceland', 'High income', 'Europe & Central Asia')
# ('IND', 'Republic of India', 'Lower middle income', 'South Asia')
# ('IDN', 'Republic of Indonesia', 'Lower middle income', 'East Asia & Pacific')
# ('IRN', 'Islamic Republic of Iran', 'Lower middle income', 'Middle East & North Africa')
# ('IRQ', 'Republic of Iraq', 'Upper middle income', 'Middle East & North Africa')
# ('IRL', 'Ireland', 'High income', 'Europe & Central Asia')
# ('ITA', 'Italian Republic', 'High income', 'Europe & Central Asia')
# ('JAM', 'Jamaica', 'Upper middle income', 'Latin America & Caribbean')
# ('JPN', 'Japan', 'High income', 'East Asia & Pacific')
# ('JOR', 'Hashemite Kingdom of Jordan', 'Upper middle income', 'Middle East & North Africa')
# ('KAZ', 'Republic of Kazakhstan', 'Upper middle income', 'Europe & Central Asia')
# ('KEN', 'Republic of Kenya', 'Lower middle income', 'Sub-Saharan Africa')
# ('KOR', 'Republic of Korea', 'High income', 'East Asia & Pacific')
# ('KWT', 'State of Kuwait', 'High income', 'Middle East & North Africa')
# ('KGZ', 'Kyrgyz Republic', 'Lower middle income', 'Europe & Central Asia')
# ('LAO', "Lao People's Democratic Republic", 'Lower middle income', 'East Asia & Pacific')
# ('LVA', 'Republic of Latvia', 'High income', 'Europe & Central Asia')
# ('LBN', 'Lebanese Republic', 'Upper middle income', 'Middle East & North Africa')
# ('LSO', 'Kingdom of Lesotho', 'Lower middle income', 'Sub-Saharan Africa')
# ('LBR', 'Republic of Liberia', 'Low income', 'Sub-Saharan Africa')
# ('LTU', 'Republic of Lithuania', 'High income', 'Europe & Central Asia')
# ('LUX', 'Grand Duchy of Luxembourg', 'High income', 'Europe & Central Asia')
# ('MDG', 'Republic of Madagascar', 'Low income', 'Sub-Saharan Africa')
# ('MWI', 'Republic of Malawi', 'Low income', 'Sub-Saharan Africa')
# ('MYS', 'Malaysia', 'Upper middle income', 'East Asia & Pacific')
# ('MDV', 'Republic of Maldives', 'Upper middle income', 'South Asia')
# ('MLI', 'Republic of Mali', 'Low income', 'Sub-Saharan Africa')
# ('MLT', 'Republic of Malta', 'High income', 'Middle East & North Africa')
# ('MRT', 'Islamic Republic of Mauritania', 'Lower middle income', 'Sub-Saharan Africa')
# ('MUS', 'Republic of Mauritius', 'Upper middle income', 'Sub-Saharan Africa')
# ('MEX', 'United Mexican States', 'Upper middle income', 'Latin America & Caribbean')
# ('MDA', 'Republic of Moldova', 'Upper middle income', 'Europe & Central Asia')
# ('MNG', 'Mongolia', 'Lower middle income', 'East Asia & Pacific')
# ('MAR', 'Kingdom of Morocco', 'Lower middle income', 'Middle East & North Africa')
# ('MOZ', 'Republic of Mozambique', 'Low income', 'Sub-Saharan Africa')
# ('NAM', 'Republic of Namibia', 'Upper middle income', 'Sub-Saharan Africa')
# ('NPL', 'Nepal', 'Lower middle income', 'South Asia')
# ('NLD', 'Kingdom of the Netherlands', 'High income', 'Europe & Central Asia')
# ('NIC', 'Republic of Nicaragua', 'Lower middle income', 'Latin America & Caribbean')
# ('NER', 'Republic of Niger', 'Low income', 'Sub-Saharan Africa')
# ('NGA', 'Federal Republic of Nigeria', 'Lower middle income', 'Sub-Saharan Africa')
# ('MKD', 'Republic of North Macedonia', 'Upper middle income', 'Europe & Central Asia')
# ('NOR', 'Kingdom of Norway', 'High income', 'Europe & Central Asia')
# ('OMN', 'Sultanate of Oman', 'High income', 'Middle East & North Africa')
# ('PAK', 'Islamic Republic of Pakistan', 'Lower middle income', 'South Asia')
# ('PAN', 'Republic of Panama', 'Upper middle income', 'Latin America & Caribbean')
# ('PNG', 'The Independent State of Papua New Guinea', 'Lower middle income', 'East Asia & Pacific')
# ('PRY', 'Republic of Paraguay', 'Upper middle income', 'Latin America & Caribbean')
# ('PER', 'Republic of Peru', 'Upper middle income', 'Latin America & Caribbean')
# ('PHL', 'Republic of the Philippines', 'Lower middle income', 'East Asia & Pacific')
# ('POL', 'Republic of Poland', 'High income', 'Europe & Central Asia')
# ('PRT', 'Portuguese Republic', 'High income', 'Europe & Central Asia')
# ('QAT', 'State of Qatar', 'High income', 'Middle East & North Africa')
# ('ROU', 'Romania', 'Upper middle income', 'Europe & Central Asia')
# ('RUS', 'Russian Federation', 'Upper middle income', 'Europe & Central Asia')
# ('RWA', 'Republic of Rwanda', 'Low income', 'Sub-Saharan Africa')
# ('SAU', 'Kingdom of Saudi Arabia', 'High income', 'Middle East & North Africa')
# ('SEN', 'Republic of Senegal', 'Lower middle income', 'Sub-Saharan Africa')
# ('SLE', 'Republic of Sierra Leone', 'Low income', 'Sub-Saharan Africa')
# ('SGP', 'Republic of Singapore', 'High income', 'East Asia & Pacific')
# ('SVK', 'Slovak Republic', 'High income', 'Europe & Central Asia')
# ('SVN', 'Republic of Slovenia', 'High income', 'Europe & Central Asia')
# ('SLB', 'Solomon Islands', 'Lower middle income', 'East Asia & Pacific')
# ('ZAF', 'Republic of South Africa', 'Upper middle income', 'Sub-Saharan Africa')
# ('ESP', 'Kingdom of Spain', 'High income', 'Europe & Central Asia')
# ('LKA', 'Democratic Socialist Republic of Sri Lanka', 'Lower middle income', 'South Asia')
# ('SUR', 'Republic of Suriname', 'Upper middle income', 'Latin America & Caribbean')
# ('SWE', 'Kingdom of Sweden', 'High income', 'Europe & Central Asia')
# ('CHE', 'Switzerland', 'High income', 'Europe & Central Asia')
# ('TJK', 'Republic of Tajikistan', 'Lower middle income', 'Europe & Central Asia')
# ('TZA', 'United Republic of Tanzania', 'Lower middle income', 'Sub-Saharan Africa')
# ('THA', 'Kingdom of Thailand', 'Upper middle income', 'East Asia & Pacific')
# ('GMB', 'Republic of The Gambia', 'Low income', 'Sub-Saharan Africa')
# ('TGO', 'Republic of Togo', 'Low income', 'Sub-Saharan Africa')
# ('TTO', 'Republic of Trinidad and Tobago', 'High income', 'Latin America & Caribbean')
# ('TUN', 'Republic of Tunisia', 'Lower middle income', 'Middle East & North Africa')
# ('TUR', 'Republic of Turkey', 'Upper middle income', 'Europe & Central Asia')
# ('TKM', 'Turkmenistan', 'Upper middle income', 'Europe & Central Asia')
# ('UGA', 'Republic of Uganda', 'Low income', 'Sub-Saharan Africa')
# ('UKR', 'Ukraine', 'Lower middle income', 'Europe & Central Asia')
# ('ARE', 'United Arab Emirates', 'High income', 'Middle East & North Africa')
# ('GBR', 'United Kingdom of Great Britain and Northern Ireland', 'High income', 'Europe & Central Asia')
# ('USA', 'United States of America', 'High income', 'North America')
# ('URY', 'Oriental Republic of Uruguay', 'High income', 'Latin America & Caribbean')
# ('VNM', 'Socialist Republic of Vietnam', 'Lower middle income', 'East Asia & Pacific')
# ('PSE', 'West Bank and Gaza', 'Lower middle income', 'Middle East & North Africa')
# ('YEM', 'Republic of Yemen', 'Low income', 'Middle East & North Africa')
# ('ZMB', 'Republic of Zambia', 'Lower middle income', 'Sub-Saharan Africa')
# ('ZWE', 'Republic of Zimbabwe', 'Lower middle income', 'Sub-Saharan Africa')
# ('VEN', 'Venezuela', 'Venezuela', 'not available')

# %%
# Creating a table
query1 = "drop table series"
query2 = "create table series (series_code varchar primary key, series_name varchar)"

try:
    cur.execute(query1)
    cur.execute(query2)
except psycopg2.Error as e:
    print(e)

# %%
# Inserting data into table
query = '''
    INSERT INTO series (series_code, series_name)
    VALUES (%s, %s)
    '''

for i in range(len(series)):
    row = series.iloc[i]
    
    try:
        cur.execute(query, (row['Code'], row['Indicator Name']))
    except psycopg2.Error as e:
        print(e)

# %%
# Displaying table content
query = "select * from series"

try:
    cur.execute(query)
except psycopg2.Error as e:
    print(e)
    
rows = cur.fetchall()
for i in rows:
    print(i)
# Out:
# ('NW.HCA.TO', 'Human capital (constant 2018 US$)')
# ('NW.HCA.PC', 'Human capital per capita (constant 2018 US$)')
# ('NW.HCA.FEMP.PC', 'Human capital per capita, employed female (constant 2018 US$)')
# ('NW.HCA.MEMP.PC', 'Human capital per capita, employed male (constant 2018 US$)')
# ('NW.HCA.FEMA.PC', 'Human capital per capita, female (constant 2018 US$)')
# ('NW.HCA.MALE.PC', 'Human capital per capita, male (constant 2018 US$)')
# ('NW.HCA.FSEM.PC', 'Human capital per capita, self-employed female (constant 2018 US$)')
# ('NW.HCA.MSEM.PC', 'Human capital per capita, self-employed male (constant 2018 US$)')
# ('NW.HCA.FEMP.TO', 'Human capital, employed female (constant 2018 US$)')
# ('NW.HCA.MEMP.TO', 'Human capital, employed male (constant 2018 US$)')
# ('NW.HCA.FEMA.TO', 'Human capital, female (constant 2018 US$)')
# ('NW.HCA.MALE.TO', 'Human capital, male (constant 2018 US$)')
# ('NW.HCA.FSEM.TO', 'Human capital, self-employed female (constant 2018 US$)')
# ('NW.HCA.MSEM.TO', 'Human capital, self-employed male (constant 2018 US$)')
# ('NW.NCA.TO', 'Natural capital (constant 2018 US$)')
# ('NW.NCA.PC', 'Natural capital per capita (constant 2018 US$)')
# ('NW.NCA.AGRI.PC', 'Natural capital per capita, agricultural land (constant 2018 US$)')
# ('NW.NCA.CROL.PC', 'Natural capital per capita, agricultural land: cropland (constant 2018 US$)')
# ('NW.NCA.PASL.PC', 'Natural capital per capita, agricultural land: pastureland (constant 2018 US$)')
# ('NW.NCA.FISH.PC', 'Natural capital per capita, fisheries (constant 2018 US$)')
# ('NW.NCA.FECO.PC', 'Natural capital per capita, forests: ecosystem services (constant 2018 US$)')
# ('NW.NCA.FTIM.PC', 'Natural capital per capita, forests: timber (constant 2018 US$)')
# ('NW.NCA.FOSL.PC', 'Natural capital per capita, fossil fuels (constant 2018 US$)')
# ('NW.NCA.MANG.PC', 'Natural capital per capita, mangroves (constant 2018 US$)')
# ('NW.NCA.SSOI.PC', 'Natural capital per capita, nonrenewable assets (constant 2018 US$)')
# ('NW.NCA.SACO.PC', 'Natural capital per capita, nonrenewable assets: coal (constant 2018 US$)')
# ('NW.NCA.SAGA.PC', 'Natural capital per capita, nonrenewable assets: gas (constant 2018 US$)')
# ('NW.NCA.MINR.PC', 'Natural capital per capita, nonrenewable assets: minerals (constant 2018 US$)')
# ('NW.NCA.SAOI.PC', 'Natural capital per capita, nonrenewable assets: oil (constant 2018 US$)')
# ('NW.NCA.PRAR.PC', 'Natural capital per capita, protected areas (constant 2018 US$)')
# ('NW.NCA.RNEW.PC', 'Natural capital per capita, renewable (constant 2018 US$)')
# ('NW.NCA.AGRI.TO', 'Natural capital, agricultural land (constant 2018 US$)')
# ('NW.NCA.CROL.TO', 'Natural capital, agricultural land: cropland (constant 2018 US$)')
# ('NW.NCA.PASL.TO', 'Natural capital, agricultural land: pastureland (constant 2018 US$)')
# ('NW.NCA.FISH.TO', 'Natural capital, fisheries (constant 2018 US$)')
# ('NW.NCA.FECO.TO', 'Natural capital, forests: ecosystem services (constant 2018 US$)')
# ('NW.NCA.FTIM.TO', 'Natural capital, forests: timber (constant 2018 US$)')
# ('NW.NCA.FOSL.TO', 'Natural capital, fossil fuels (constant 2018 US$)')
# ('NW.NCA.MANG.TO', 'Natural capital, mangroves (constant 2018 US$)')
# ('NW.NCA.SSOI.TO', 'Natural capital, nonrenewable assets (constant 2018 US$)')
# ('NW.NCA.SACO.TO', 'Natural capital, nonrenewable assets: coal (constant 2018 US$)')
# ('NW.NCA.SAGA.TO', 'Natural capital, nonrenewable assets: gas (constant 2018 US$)')
# ('NW.NCA.MINR.TO', 'Natural capital, nonrenewable assets: minerals (constant 2018 US$)')
# ('NW.NCA.SAOI.TO', 'Natural capital, nonrenewable assets: oil (constant 2018 US$)')
# ('NW.NCA.PRAR.TO', 'Natural capital, protected areas (constant 2018 US$)')
# ('NW.NCA.RNEW.TO', 'Natural capital, renewable (constant 2018 US$)')
# ('NW.NFA.TO', 'Net foreign assets (constant 2018 US$)')
# ('NW.NFA.PC', 'Net foreign assets per capita (constant 2018 US$)')
# ('NW.PCA.TO', 'Produced capital (constant 2018 US$)')
# ('NW.PCA.PC', 'Produced capital per capita (constant 2018 US$)')
# ('NW.TOW.TO', 'Total wealth (constant 2018 US$)')
# ('NW.TOW.PC', 'Total wealth per capita (constant 2018 US$)')

# %%
# Creating a table
query = "CREATE TABLE accounts (country_name VARCHAR, country_code VARCHAR, series_name VARCHAR, \
        series_code VARCHAR, yr2018 NUMERIC(20, 5), PRIMARY KEY (country_code, series_code),  \
        FOREIGN KEY (country_code) REFERENCES countries(country_code), \
        FOREIGN KEY (series_code) REFERENCES series(series_code))"

try:
    cur.execute(query)
except psycopg2.Error as e:
    print(e)

# %%
# Inserting data into table
query = '''
    INSERT INTO accounts (country_name, country_code, series_name, series_code, yr2018)
    VALUES (%s, %s, %s, %s, %s)
    '''

for i in range(len(accounts)):
    row = accounts.iloc[i]
    
    try:
        cur.execute(query, (row['Country Name'], row['Country Code'], row['Series Name'], \
                            row['Series Code'], row['YR2018']))
    except psycopg2.Error as e:
        print(e)

# %%
# Displaying table content
query = "select * from accounts limit 10"

try:
    cur.execute(query)
except psycopg2.Error as e:
    print(e)
    
rows = cur.fetchall()
for i in rows:
    print(i)
# Out:
# ('Albania', 'ALB', 'Human capital (constant 2018 US$)', 'NW.HCA.TO', Decimal('81200000000.00000'))
# ('Albania', 'ALB', 'Human capital per capita (constant 2018 US$)', 'NW.HCA.PC', Decimal('28333.68000'))
# ('Albania', 'ALB', 'Human capital per capita, employed female (constant 2018 US$)', 'NW.HCA.FEMP.PC', Decimal('3312.92700'))
# ('Albania', 'ALB', 'Human capital per capita, employed male (constant 2018 US$)', 'NW.HCA.MEMP.PC', Decimal('19245.19000'))
# ('Albania', 'ALB', 'Human capital per capita, female (constant 2018 US$)', 'NW.HCA.FEMA.PC', Decimal('4161.13700'))
# ('Albania', 'ALB', 'Human capital per capita, male (constant 2018 US$)', 'NW.HCA.MALE.PC', Decimal('24172.54000'))
# ('Albania', 'ALB', 'Human capital per capita, self-employed female (constant 2018 US$)', 'NW.HCA.FSEM.PC', Decimal('848.21040'))
# ('Albania', 'ALB', 'Human capital per capita, self-employed male (constant 2018 US$)', 'NW.HCA.MSEM.PC', Decimal('4927.35500'))
# ('Albania', 'ALB', 'Human capital, employed female (constant 2018 US$)', 'NW.HCA.FEMP.TO', Decimal('9500000000.00000'))
# ('Albania', 'ALB', 'Human capital, employed male (constant 2018 US$)', 'NW.HCA.MEMP.TO', Decimal('55200000000.00000'))

# %% [markdown]
# # CHECKING DATA MODEL

# %%
# Using join to check tables
query = '''
    SELECT accounts.country_name, accounts.series_code, countries.income_group, series.series_name, accounts.yr2018
    FROM accounts
    JOIN countries ON accounts.country_code = countries.country_code
    JOIN series ON accounts.series_code = series.series_code;
'''

try:
    cur.execute(query)
except psycopg2.Error as e:
    print(e)
    
rows = cur.fetchall()
    
column_names = [desc[0] for desc in cur.description]
df = pd.DataFrame(rows, columns=column_names)
df
# Out:
#                   country_name     series_code         income_group
# 0                      Albania       NW.HCA.TO  Upper middle income  \
# 1                      Albania       NW.HCA.PC  Upper middle income
# 2                      Albania  NW.HCA.FEMP.PC  Upper middle income
# 3                      Albania  NW.HCA.MEMP.PC  Upper middle income
# 4                      Albania  NW.HCA.FEMA.PC  Upper middle income
# 5                      Albania  NW.HCA.MALE.PC  Upper middle income
# 6                      Albania  NW.HCA.FSEM.PC  Upper middle income
# 7                      Albania  NW.HCA.MSEM.PC  Upper middle income
# 8                      Albania  NW.HCA.FEMP.TO  Upper middle income
# 9                      Albania  NW.HCA.MEMP.TO  Upper middle income
# 10                     Albania  NW.HCA.FEMA.TO  Upper middle income
# 11                     Albania  NW.HCA.MALE.TO  Upper middle income
# 12                     Albania  NW.HCA.FSEM.TO  Upper middle income
# 13                     Albania  NW.HCA.MSEM.TO  Upper middle income
# 14                     Albania       NW.NCA.TO  Upper middle income
# 15                     Albania       NW.NCA.PC  Upper middle income
# 16                     Albania  NW.NCA.AGRI.PC  Upper middle income
# 17                     Albania  NW.NCA.CROL.PC  Upper middle income
# 18                     Albania  NW.NCA.PASL.PC  Upper middle income
# 19                     Albania  NW.NCA.FISH.PC  Upper middle income
# 20                     Albania  NW.NCA.FECO.PC  Upper middle income
# 21                     Albania  NW.NCA.FTIM.PC  Upper middle income
# 22                     Albania  NW.NCA.FOSL.PC  Upper middle income
# 23                     Albania  NW.NCA.MANG.PC  Upper middle income
# 24                     Albania  NW.NCA.SSOI.PC  Upper middle income
# 25                     Albania  NW.NCA.SACO.PC  Upper middle income
# 26                     Albania  NW.NCA.SAGA.PC  Upper middle income
# 27                     Albania  NW.NCA.MINR.PC  Upper middle income
# 28                     Albania  NW.NCA.SAOI.PC  Upper middle income
# 29                     Albania  NW.NCA.PRAR.PC  Upper middle income
# 30                     Albania  NW.NCA.RNEW.PC  Upper middle income
# 31                     Albania  NW.NCA.AGRI.TO  Upper middle income
# 32                     Albania  NW.NCA.CROL.TO  Upper middle income
# 33                     Albania  NW.NCA.PASL.TO  Upper middle income
# 34                     Albania  NW.NCA.FISH.TO  Upper middle income
# 35                     Albania  NW.NCA.FECO.TO  Upper middle income
# 36                     Albania  NW.NCA.FTIM.TO  Upper middle income
# 37                     Albania  NW.NCA.FOSL.TO  Upper middle income
# 38                     Albania  NW.NCA.MANG.TO  Upper middle income
# 39                     Albania  NW.NCA.SSOI.TO  Upper middle income
# 40                     Albania  NW.NCA.SACO.TO  Upper middle income
# 41                     Albania  NW.NCA.SAGA.TO  Upper middle income
# 42                     Albania  NW.NCA.MINR.TO  Upper middle income
# 43                     Albania  NW.NCA.SAOI.TO  Upper middle income
# 44                     Albania  NW.NCA.PRAR.TO  Upper middle income
# 45                     Albania  NW.NCA.RNEW.TO  Upper middle income
# 46                     Albania       NW.NFA.TO  Upper middle income
# 47                     Albania       NW.NFA.PC  Upper middle income
# 48                     Albania       NW.PCA.TO  Upper middle income
# 49                     Albania       NW.PCA.PC  Upper middle income
# 50                     Albania       NW.TOW.TO  Upper middle income
# 51                     Albania       NW.TOW.PC  Upper middle income
# 52                   Argentina       NW.HCA.TO  Upper middle income
# 53                   Argentina       NW.HCA.PC  Upper middle income
# 54                   Argentina  NW.HCA.FEMP.PC  Upper middle income
# 55                   Argentina  NW.HCA.MEMP.PC  Upper middle income
# 56                   Argentina  NW.HCA.FEMA.PC  Upper middle income
# 57                   Argentina  NW.HCA.MALE.PC  Upper middle income
# 58                   Argentina  NW.HCA.FSEM.PC  Upper middle income
# 59                   Argentina  NW.HCA.MSEM.PC  Upper middle income
# 60                   Argentina  NW.HCA.FEMP.TO  Upper middle income
# 61                   Argentina  NW.HCA.MEMP.TO  Upper middle income
# 62                   Argentina  NW.HCA.FEMA.TO  Upper middle income
# 63                   Argentina  NW.HCA.MALE.TO  Upper middle income
# 64                   Argentina  NW.HCA.FSEM.TO  Upper middle income
# 65                   Argentina  NW.HCA.MSEM.TO  Upper middle income
# 66                   Argentina       NW.NCA.TO  Upper middle income
# 67                   Argentina       NW.NCA.PC  Upper middle income
# 68                   Argentina  NW.NCA.AGRI.PC  Upper middle income
# 69                   Argentina  NW.NCA.CROL.PC  Upper middle income
# 70                   Argentina  NW.NCA.PASL.PC  Upper middle income
# 71                   Argentina  NW.NCA.FISH.PC  Upper middle income
# 72                   Argentina  NW.NCA.FECO.PC  Upper middle income
# 73                   Argentina  NW.NCA.FTIM.PC  Upper middle income
# 74                   Argentina  NW.NCA.FOSL.PC  Upper middle income
# 75                   Argentina  NW.NCA.MANG.PC  Upper middle income
# 76                   Argentina  NW.NCA.SSOI.PC  Upper middle income
# 77                   Argentina  NW.NCA.SACO.PC  Upper middle income
# 78                   Argentina  NW.NCA.SAGA.PC  Upper middle income
# 79                   Argentina  NW.NCA.MINR.PC  Upper middle income
# 80                   Argentina  NW.NCA.SAOI.PC  Upper middle income
# 81                   Argentina  NW.NCA.PRAR.PC  Upper middle income
# 82                   Argentina  NW.NCA.RNEW.PC  Upper middle income
# 83                   Argentina  NW.NCA.AGRI.TO  Upper middle income
# 84                   Argentina  NW.NCA.CROL.TO  Upper middle income
# 85                   Argentina  NW.NCA.PASL.TO  Upper middle income
# 86                   Argentina  NW.NCA.FISH.TO  Upper middle income
# 87                   Argentina  NW.NCA.FECO.TO  Upper middle income
# 88                   Argentina  NW.NCA.FTIM.TO  Upper middle income
# 89                   Argentina  NW.NCA.FOSL.TO  Upper middle income
# 90                   Argentina  NW.NCA.MANG.TO  Upper middle income
# 91                   Argentina  NW.NCA.SSOI.TO  Upper middle income
# 92                   Argentina  NW.NCA.SACO.TO  Upper middle income
# 93                   Argentina  NW.NCA.SAGA.TO  Upper middle income
# 94                   Argentina  NW.NCA.MINR.TO  Upper middle income
# 95                   Argentina  NW.NCA.SAOI.TO  Upper middle income
# 96                   Argentina  NW.NCA.PRAR.TO  Upper middle income
# 97                   Argentina  NW.NCA.RNEW.TO  Upper middle income
# 98                   Argentina       NW.NFA.TO  Upper middle income
# 99                   Argentina       NW.NFA.PC  Upper middle income
# 100                  Argentina       NW.PCA.TO  Upper middle income
# 101                  Argentina       NW.PCA.PC  Upper middle income
# 102                  Argentina       NW.TOW.TO  Upper middle income
# 103                  Argentina       NW.TOW.PC  Upper middle income
# 104                    Armenia       NW.HCA.TO  Upper middle income
# 105                    Armenia       NW.HCA.PC  Upper middle income
# 106                    Armenia  NW.HCA.FEMP.PC  Upper middle income
# 107                    Armenia  NW.HCA.MEMP.PC  Upper middle income
# 108                    Armenia  NW.HCA.FEMA.PC  Upper middle income
# 109                    Armenia  NW.HCA.MALE.PC  Upper middle income
# 110                    Armenia  NW.HCA.FSEM.PC  Upper middle income
# 111                    Armenia  NW.HCA.MSEM.PC  Upper middle income
# 112                    Armenia  NW.HCA.FEMP.TO  Upper middle income
# 113                    Armenia  NW.HCA.MEMP.TO  Upper middle income
# 114                    Armenia  NW.HCA.FEMA.TO  Upper middle income
# 115                    Armenia  NW.HCA.MALE.TO  Upper middle income
# 116                    Armenia  NW.HCA.FSEM.TO  Upper middle income
# 117                    Armenia  NW.HCA.MSEM.TO  Upper middle income
# 118                    Armenia       NW.NCA.TO  Upper middle income
# 119                    Armenia       NW.NCA.PC  Upper middle income
# 120                    Armenia  NW.NCA.AGRI.PC  Upper middle income
# 121                    Armenia  NW.NCA.CROL.PC  Upper middle income
# 122                    Armenia  NW.NCA.PASL.PC  Upper middle income
# 123                    Armenia  NW.NCA.FISH.PC  Upper middle income
# 124                    Armenia  NW.NCA.FECO.PC  Upper middle income
# 125                    Armenia  NW.NCA.FTIM.PC  Upper middle income
# 126                    Armenia  NW.NCA.FOSL.PC  Upper middle income
# 127                    Armenia  NW.NCA.MANG.PC  Upper middle income
# 128                    Armenia  NW.NCA.SSOI.PC  Upper middle income
# 129                    Armenia  NW.NCA.SACO.PC  Upper middle income
# 130                    Armenia  NW.NCA.SAGA.PC  Upper middle income
# 131                    Armenia  NW.NCA.MINR.PC  Upper middle income
# 132                    Armenia  NW.NCA.SAOI.PC  Upper middle income
# 133                    Belarus       NW.TOW.TO  Upper middle income
# 134                    Armenia  NW.NCA.PRAR.PC  Upper middle income
# 135                    Armenia  NW.NCA.RNEW.PC  Upper middle income
# 136                    Armenia  NW.NCA.AGRI.TO  Upper middle income
# 137                    Armenia  NW.NCA.CROL.TO  Upper middle income
# 138                    Armenia  NW.NCA.PASL.TO  Upper middle income
# 139                    Armenia  NW.NCA.FISH.TO  Upper middle income
# 140                    Armenia  NW.NCA.FECO.TO  Upper middle income
# 141                    Armenia  NW.NCA.FTIM.TO  Upper middle income
# 142                    Armenia  NW.NCA.FOSL.TO  Upper middle income
# 143                    Armenia  NW.NCA.MANG.TO  Upper middle income
# 144                    Armenia  NW.NCA.SSOI.TO  Upper middle income
# 145                    Armenia  NW.NCA.SACO.TO  Upper middle income
# 146                    Armenia  NW.NCA.SAGA.TO  Upper middle income
# 147                    Armenia  NW.NCA.MINR.TO  Upper middle income
# 148                    Armenia  NW.NCA.SAOI.TO  Upper middle income
# 149                    Armenia  NW.NCA.PRAR.TO  Upper middle income
# 150                    Armenia  NW.NCA.RNEW.TO  Upper middle income
# 151                    Armenia       NW.NFA.TO  Upper middle income
# 152                    Armenia       NW.NFA.PC  Upper middle income
# 153                    Armenia       NW.PCA.TO  Upper middle income
# 154                    Armenia       NW.PCA.PC  Upper middle income
# 155                    Armenia       NW.TOW.TO  Upper middle income
# 156                    Armenia       NW.TOW.PC  Upper middle income
# 157                  Australia       NW.HCA.TO          High income
# 158                  Australia       NW.HCA.PC          High income
# 159                  Australia  NW.HCA.FEMP.PC          High income
# 160                  Australia  NW.HCA.MEMP.PC          High income
# 161                  Australia  NW.HCA.FEMA.PC          High income
# 162                  Australia  NW.HCA.MALE.PC          High income
# 163                  Australia  NW.HCA.FSEM.PC          High income
# 164                  Australia  NW.HCA.MSEM.PC          High income
# 165                  Australia  NW.HCA.FEMP.TO          High income
# 166                  Australia  NW.HCA.MEMP.TO          High income
# 167                  Australia  NW.HCA.FEMA.TO          High income
# 168                  Australia  NW.HCA.MALE.TO          High income
# 169                  Australia  NW.HCA.FSEM.TO          High income
# 170                  Australia  NW.HCA.MSEM.TO          High income
# 171                  Australia       NW.NCA.TO          High income
# 172                  Australia       NW.NCA.PC          High income
# 173                  Australia  NW.NCA.AGRI.PC          High income
# 174                  Australia  NW.NCA.CROL.PC          High income
# 175                  Australia  NW.NCA.PASL.PC          High income
# 176                  Australia  NW.NCA.FISH.PC          High income
# 177                  Australia  NW.NCA.FECO.PC          High income
# 178                  Australia  NW.NCA.FTIM.PC          High income
# 179                  Australia  NW.NCA.FOSL.PC          High income
# 180                  Australia  NW.NCA.MANG.PC          High income
# 181                  Australia  NW.NCA.SSOI.PC          High income
# 182                  Australia  NW.NCA.SACO.PC          High income
# 183                  Australia  NW.NCA.SAGA.PC          High income
# 184                  Australia  NW.NCA.MINR.PC          High income
# 185                  Australia  NW.NCA.SAOI.PC          High income
# 186                  Australia  NW.NCA.PRAR.PC          High income
# 187                  Australia  NW.NCA.RNEW.PC          High income
# 188                  Australia  NW.NCA.AGRI.TO          High income
# 189                  Australia  NW.NCA.CROL.TO          High income
# 190                  Australia  NW.NCA.PASL.TO          High income
# 191                  Australia  NW.NCA.FISH.TO          High income
# 192                  Australia  NW.NCA.FECO.TO          High income
# 193                  Australia  NW.NCA.FTIM.TO          High income
# 194                  Australia  NW.NCA.FOSL.TO          High income
# 195                  Australia  NW.NCA.MANG.TO          High income
# 196                  Australia  NW.NCA.SSOI.TO          High income
# 197                  Australia  NW.NCA.SACO.TO          High income
# 198                  Australia  NW.NCA.SAGA.TO          High income
# 199                  Australia  NW.NCA.MINR.TO          High income
# 200                  Australia  NW.NCA.SAOI.TO          High income
# 201                  Australia  NW.NCA.PRAR.TO          High income
# 202                  Australia  NW.NCA.RNEW.TO          High income
# 203                  Australia       NW.NFA.TO          High income
# 204                  Australia       NW.NFA.PC          High income
# 205                  Australia       NW.PCA.TO          High income
# 206                  Australia       NW.PCA.PC          High income
# 207                  Australia       NW.TOW.TO          High income
# 208                  Australia       NW.TOW.PC          High income
# 209                    Austria       NW.HCA.TO          High income
# 210                    Austria       NW.HCA.PC          High income
# 211                    Austria  NW.HCA.FEMP.PC          High income
# 212                    Austria  NW.HCA.MEMP.PC          High income
# 213                    Austria  NW.HCA.FEMA.PC          High income
# 214                    Austria  NW.HCA.MALE.PC          High income
# 215                    Austria  NW.HCA.FSEM.PC          High income
# 216                    Austria  NW.HCA.MSEM.PC          High income
# 217                    Austria  NW.HCA.FEMP.TO          High income
# 218                    Austria  NW.HCA.MEMP.TO          High income
# 219                    Austria  NW.HCA.FEMA.TO          High income
# 220                    Austria  NW.HCA.MALE.TO          High income
# 221                    Austria  NW.HCA.FSEM.TO          High income
# 222                    Austria  NW.HCA.MSEM.TO          High income
# 223                    Austria       NW.NCA.TO          High income
# 224                    Austria       NW.NCA.PC          High income
# 225                    Austria  NW.NCA.AGRI.PC          High income
# 226                    Austria  NW.NCA.CROL.PC          High income
# 227                    Austria  NW.NCA.PASL.PC          High income
# 228                    Austria  NW.NCA.FISH.PC          High income
# 229                    Austria  NW.NCA.FECO.PC          High income
# 230                    Austria  NW.NCA.FTIM.PC          High income
# 231                    Austria  NW.NCA.FOSL.PC          High income
# 232                    Austria  NW.NCA.MANG.PC          High income
# 233                    Austria  NW.NCA.SSOI.PC          High income
# 234                    Austria  NW.NCA.SACO.PC          High income
# 235                    Austria  NW.NCA.SAGA.PC          High income
# 236                    Austria  NW.NCA.MINR.PC          High income
# 237                    Austria  NW.NCA.SAOI.PC          High income
# 238                    Austria  NW.NCA.PRAR.PC          High income
# 239                    Austria  NW.NCA.RNEW.PC          High income
# 240                    Austria  NW.NCA.AGRI.TO          High income
# 241                    Austria  NW.NCA.CROL.TO          High income
# 242                    Austria  NW.NCA.PASL.TO          High income
# 243                    Austria  NW.NCA.FISH.TO          High income
# 244                    Austria  NW.NCA.FECO.TO          High income
# 245                    Austria  NW.NCA.FTIM.TO          High income
# 246                    Austria  NW.NCA.FOSL.TO          High income
# 247                    Austria  NW.NCA.MANG.TO          High income
# 248                    Austria  NW.NCA.SSOI.TO          High income
# 249                    Austria  NW.NCA.SACO.TO          High income
# 250                    Austria  NW.NCA.SAGA.TO          High income
# 251                    Austria  NW.NCA.MINR.TO          High income
# 252                    Austria  NW.NCA.SAOI.TO          High income
# 253                    Austria  NW.NCA.PRAR.TO          High income
# 254                    Austria  NW.NCA.RNEW.TO          High income
# 255                    Austria       NW.NFA.TO          High income
# 256                    Austria       NW.NFA.PC          High income
# 257                    Austria       NW.PCA.TO          High income
# 258                    Austria       NW.PCA.PC          High income
# 259                    Austria       NW.TOW.TO          High income
# 260                    Austria       NW.TOW.PC          High income
# 261                 Azerbaijan       NW.HCA.TO  Upper middle income
# 262                 Azerbaijan       NW.HCA.PC  Upper middle income
# 263                 Azerbaijan  NW.HCA.FEMP.PC  Upper middle income
# 264                 Azerbaijan  NW.HCA.MEMP.PC  Upper middle income
# 265                 Azerbaijan  NW.HCA.FEMA.PC  Upper middle income
# 266                 Azerbaijan  NW.HCA.MALE.PC  Upper middle income
# 267                 Azerbaijan  NW.HCA.FSEM.PC  Upper middle income
# 268                 Azerbaijan  NW.HCA.MSEM.PC  Upper middle income
# 269                 Azerbaijan  NW.HCA.FEMP.TO  Upper middle income
# 270                 Azerbaijan  NW.HCA.MEMP.TO  Upper middle income
# 271                 Azerbaijan  NW.HCA.FEMA.TO  Upper middle income
# 272                 Azerbaijan  NW.HCA.MALE.TO  Upper middle income
# 273                 Azerbaijan  NW.HCA.FSEM.TO  Upper middle income
# 274                 Azerbaijan  NW.HCA.MSEM.TO  Upper middle income
# 275                 Azerbaijan       NW.NCA.TO  Upper middle income
# 276                 Azerbaijan       NW.NCA.PC  Upper middle income
# 277                 Azerbaijan  NW.NCA.AGRI.PC  Upper middle income
# 278                 Azerbaijan  NW.NCA.CROL.PC  Upper middle income
# 279                 Azerbaijan  NW.NCA.PASL.PC  Upper middle income
# 280                 Azerbaijan  NW.NCA.FISH.PC  Upper middle income
# 281                 Azerbaijan  NW.NCA.FECO.PC  Upper middle income
# 282                 Azerbaijan  NW.NCA.FTIM.PC  Upper middle income
# 283                 Azerbaijan  NW.NCA.FOSL.PC  Upper middle income
# 284                 Azerbaijan  NW.NCA.MANG.PC  Upper middle income
# 285                 Azerbaijan  NW.NCA.SSOI.PC  Upper middle income
# 286                 Azerbaijan  NW.NCA.SACO.PC  Upper middle income
# 287                 Azerbaijan  NW.NCA.SAGA.PC  Upper middle income
# 288                 Azerbaijan  NW.NCA.MINR.PC  Upper middle income
# 289                 Azerbaijan  NW.NCA.SAOI.PC  Upper middle income
# 290                 Azerbaijan  NW.NCA.PRAR.PC  Upper middle income
# 291                 Azerbaijan  NW.NCA.RNEW.PC  Upper middle income
# 292                 Azerbaijan  NW.NCA.AGRI.TO  Upper middle income
# 293                 Azerbaijan  NW.NCA.CROL.TO  Upper middle income
# 294                 Azerbaijan  NW.NCA.PASL.TO  Upper middle income
# 295                 Azerbaijan  NW.NCA.FISH.TO  Upper middle income
# 296                 Azerbaijan  NW.NCA.FECO.TO  Upper middle income
# 297                 Azerbaijan  NW.NCA.FTIM.TO  Upper middle income
# 298                 Azerbaijan  NW.NCA.FOSL.TO  Upper middle income
# 299                 Azerbaijan  NW.NCA.MANG.TO  Upper middle income
# 300                 Azerbaijan  NW.NCA.SSOI.TO  Upper middle income
# 301                 Azerbaijan  NW.NCA.SACO.TO  Upper middle income
# 302                 Azerbaijan  NW.NCA.SAGA.TO  Upper middle income
# 303                 Azerbaijan  NW.NCA.MINR.TO  Upper middle income
# 304                 Azerbaijan  NW.NCA.SAOI.TO  Upper middle income
# 305                 Azerbaijan  NW.NCA.PRAR.TO  Upper middle income
# 306                 Azerbaijan  NW.NCA.RNEW.TO  Upper middle income
# 307                 Azerbaijan       NW.NFA.TO  Upper middle income
# 308                 Azerbaijan       NW.NFA.PC  Upper middle income
# 309                 Azerbaijan       NW.PCA.TO  Upper middle income
# 310                 Azerbaijan       NW.PCA.PC  Upper middle income
# 311                 Azerbaijan       NW.TOW.TO  Upper middle income
# 312                 Azerbaijan       NW.TOW.PC  Upper middle income
# 313                    Bahrain       NW.HCA.TO          High income
# 314                    Bahrain       NW.HCA.PC          High income
# 315                    Bahrain  NW.HCA.FEMP.PC          High income
# 316                    Bahrain  NW.HCA.MEMP.PC          High income
# 317                    Bahrain  NW.HCA.FEMA.PC          High income
# 318                    Bahrain  NW.HCA.MALE.PC          High income
# 319                    Bahrain  NW.HCA.FSEM.PC          High income
# 320                    Bahrain  NW.HCA.MSEM.PC          High income
# 321                    Bahrain  NW.HCA.FEMP.TO          High income
# 322                    Bahrain  NW.HCA.MEMP.TO          High income
# 323                    Bahrain  NW.HCA.FEMA.TO          High income
# 324                    Bahrain  NW.HCA.MALE.TO          High income
# 325                    Bahrain  NW.HCA.FSEM.TO          High income
# 326                    Bahrain  NW.HCA.MSEM.TO          High income
# 327                    Bahrain       NW.NCA.TO          High income
# 328                    Bahrain       NW.NCA.PC          High income
# 329                    Bahrain  NW.NCA.AGRI.PC          High income
# 330                    Bahrain  NW.NCA.CROL.PC          High income
# 331                    Bahrain  NW.NCA.PASL.PC          High income
# 332                    Bahrain  NW.NCA.FISH.PC          High income
# 333                    Bahrain  NW.NCA.FECO.PC          High income
# 334                    Bahrain  NW.NCA.FTIM.PC          High income
# 335                    Bahrain  NW.NCA.FOSL.PC          High income
# 336                    Bahrain  NW.NCA.MANG.PC          High income
# 337                    Bahrain  NW.NCA.SSOI.PC          High income
# 338                    Bahrain  NW.NCA.SACO.PC          High income
# 339                    Bahrain  NW.NCA.SAGA.PC          High income
# 340                    Bahrain  NW.NCA.MINR.PC          High income
# 341                    Bahrain  NW.NCA.SAOI.PC          High income
# 342                    Bahrain  NW.NCA.PRAR.PC          High income
# 343                    Bahrain  NW.NCA.RNEW.PC          High income
# 344                    Bahrain  NW.NCA.AGRI.TO          High income
# 345                    Bahrain  NW.NCA.CROL.TO          High income
# 346                    Bahrain  NW.NCA.PASL.TO          High income
# 347                    Bahrain  NW.NCA.FISH.TO          High income
# 348                    Bahrain  NW.NCA.FECO.TO          High income
# 349                    Bahrain  NW.NCA.FTIM.TO          High income
# 350                    Bahrain  NW.NCA.FOSL.TO          High income
# 351                    Bahrain  NW.NCA.MANG.TO          High income
# 352                    Bahrain  NW.NCA.SSOI.TO          High income
# 353                    Bahrain  NW.NCA.SACO.TO          High income
# 354                    Bahrain  NW.NCA.SAGA.TO          High income
# 355                    Bahrain  NW.NCA.MINR.TO          High income
# 356                    Bahrain  NW.NCA.SAOI.TO          High income
# 357                    Bahrain  NW.NCA.PRAR.TO          High income
# 358                    Bahrain  NW.NCA.RNEW.TO          High income
# 359                    Bahrain       NW.NFA.TO          High income
# 360                    Bahrain       NW.NFA.PC          High income
# 361                    Bahrain       NW.PCA.TO          High income
# 362                    Bahrain       NW.PCA.PC          High income
# 363                    Bahrain       NW.TOW.TO          High income
# 364                    Bahrain       NW.TOW.PC          High income
# 365                 Bangladesh       NW.HCA.TO  Lower middle income
# 366                 Bangladesh       NW.HCA.PC  Lower middle income
# 367                 Bangladesh  NW.HCA.FEMP.PC  Lower middle income
# 368                 Bangladesh  NW.HCA.MEMP.PC  Lower middle income
# 369                 Bangladesh  NW.HCA.FEMA.PC  Lower middle income
# 370                 Bangladesh  NW.HCA.MALE.PC  Lower middle income
# 371                 Bangladesh  NW.HCA.FSEM.PC  Lower middle income
# 372                 Bangladesh  NW.HCA.MSEM.PC  Lower middle income
# 373                 Bangladesh  NW.HCA.FEMP.TO  Lower middle income
# 374                 Bangladesh  NW.HCA.MEMP.TO  Lower middle income
# 375                 Bangladesh  NW.HCA.FEMA.TO  Lower middle income
# 376                 Bangladesh  NW.HCA.MALE.TO  Lower middle income
# 377                 Bangladesh  NW.HCA.FSEM.TO  Lower middle income
# 378                 Bangladesh  NW.HCA.MSEM.TO  Lower middle income
# 379                 Bangladesh       NW.NCA.TO  Lower middle income
# 380                 Bangladesh       NW.NCA.PC  Lower middle income
# 381                 Bangladesh  NW.NCA.AGRI.PC  Lower middle income
# 382                 Bangladesh  NW.NCA.CROL.PC  Lower middle income
# 383                 Bangladesh  NW.NCA.PASL.PC  Lower middle income
# 384                 Bangladesh  NW.NCA.FISH.PC  Lower middle income
# 385                 Bangladesh  NW.NCA.FECO.PC  Lower middle income
# 386                 Bangladesh  NW.NCA.FTIM.PC  Lower middle income
# 387                 Bangladesh  NW.NCA.FOSL.PC  Lower middle income
# 388                 Bangladesh  NW.NCA.MANG.PC  Lower middle income
# 389                 Bangladesh  NW.NCA.SSOI.PC  Lower middle income
# 390                 Bangladesh  NW.NCA.SACO.PC  Lower middle income
# 391                 Bangladesh  NW.NCA.SAGA.PC  Lower middle income
# 392                 Bangladesh  NW.NCA.MINR.PC  Lower middle income
# 393                 Bangladesh  NW.NCA.SAOI.PC  Lower middle income
# 394                 Bangladesh  NW.NCA.PRAR.PC  Lower middle income
# 395                 Bangladesh  NW.NCA.RNEW.PC  Lower middle income
# 396                 Bangladesh  NW.NCA.AGRI.TO  Lower middle income
# 397                 Bangladesh  NW.NCA.CROL.TO  Lower middle income
# 398                 Bangladesh  NW.NCA.PASL.TO  Lower middle income
# 399                 Bangladesh  NW.NCA.FISH.TO  Lower middle income
# 400                 Bangladesh  NW.NCA.FECO.TO  Lower middle income
# 401                 Bangladesh  NW.NCA.FTIM.TO  Lower middle income
# 402                 Bangladesh  NW.NCA.FOSL.TO  Lower middle income
# 403                 Bangladesh  NW.NCA.MANG.TO  Lower middle income
# 404                 Bangladesh  NW.NCA.SSOI.TO  Lower middle income
# 405                 Bangladesh  NW.NCA.SACO.TO  Lower middle income
# 406                 Bangladesh  NW.NCA.SAGA.TO  Lower middle income
# 407                 Bangladesh  NW.NCA.MINR.TO  Lower middle income
# 408                 Bangladesh  NW.NCA.SAOI.TO  Lower middle income
# 409                 Bangladesh  NW.NCA.PRAR.TO  Lower middle income
# 410                 Bangladesh  NW.NCA.RNEW.TO  Lower middle income
# 411                 Bangladesh       NW.NFA.TO  Lower middle income
# 412                 Bangladesh       NW.NFA.PC  Lower middle income
# 413                 Bangladesh       NW.PCA.TO  Lower middle income
# 414                 Bangladesh       NW.PCA.PC  Lower middle income
# 415                 Bangladesh       NW.TOW.TO  Lower middle income
# 416                 Bangladesh       NW.TOW.PC  Lower middle income
# 417                    Belarus       NW.HCA.TO  Upper middle income
# 418                    Belarus       NW.HCA.PC  Upper middle income
# 419                    Belarus  NW.HCA.FEMP.PC  Upper middle income
# 420                    Belarus  NW.HCA.MEMP.PC  Upper middle income
# 421                    Belarus  NW.HCA.FEMA.PC  Upper middle income
# 422                    Belarus  NW.HCA.MALE.PC  Upper middle income
# 423                    Belarus  NW.HCA.FSEM.PC  Upper middle income
# 424                    Belarus  NW.HCA.MSEM.PC  Upper middle income
# 425                    Belarus  NW.HCA.FEMP.TO  Upper middle income
# 426                    Belarus  NW.HCA.MEMP.TO  Upper middle income
# 427                    Belarus  NW.HCA.FEMA.TO  Upper middle income
# 428                    Belarus  NW.HCA.MALE.TO  Upper middle income
# 429                    Belarus  NW.HCA.FSEM.TO  Upper middle income
# 430                    Belarus  NW.HCA.MSEM.TO  Upper middle income
# 431                    Belarus       NW.NCA.TO  Upper middle income
# 432                    Belarus       NW.NCA.PC  Upper middle income
# 433                    Belarus  NW.NCA.AGRI.PC  Upper middle income
# 434                    Belarus  NW.NCA.CROL.PC  Upper middle income
# 435                    Belarus  NW.NCA.PASL.PC  Upper middle income
# 436                    Belarus  NW.NCA.FISH.PC  Upper middle income
# 437                    Belarus  NW.NCA.FECO.PC  Upper middle income
# 438                    Belarus  NW.NCA.FTIM.PC  Upper middle income
# 439                    Belarus  NW.NCA.FOSL.PC  Upper middle income
# 440                    Belarus  NW.NCA.MANG.PC  Upper middle income
# 441                    Belarus  NW.NCA.SSOI.PC  Upper middle income
# 442                    Belarus  NW.NCA.SACO.PC  Upper middle income
# 443                    Belarus  NW.NCA.SAGA.PC  Upper middle income
# 444                    Belarus  NW.NCA.MINR.PC  Upper middle income
# 445                    Belarus  NW.NCA.SAOI.PC  Upper middle income
# 446                    Belarus  NW.NCA.PRAR.PC  Upper middle income
# 447                    Belarus  NW.NCA.RNEW.PC  Upper middle income
# 448                    Belarus  NW.NCA.AGRI.TO  Upper middle income
# 449                    Belarus  NW.NCA.CROL.TO  Upper middle income
# 450                    Belarus  NW.NCA.PASL.TO  Upper middle income
# 451                    Belarus  NW.NCA.FISH.TO  Upper middle income
# 452                    Belarus  NW.NCA.FECO.TO  Upper middle income
# 453                    Belarus  NW.NCA.FTIM.TO  Upper middle income
# 454                    Belarus  NW.NCA.FOSL.TO  Upper middle income
# 455                    Belarus  NW.NCA.MANG.TO  Upper middle income
# 456                    Belarus  NW.NCA.SSOI.TO  Upper middle income
# 457                    Belarus  NW.NCA.SACO.TO  Upper middle income
# 458                    Belarus  NW.NCA.SAGA.TO  Upper middle income
# 459                    Belarus  NW.NCA.MINR.TO  Upper middle income
# 460                    Belarus  NW.NCA.SAOI.TO  Upper middle income
# 461                    Belarus  NW.NCA.PRAR.TO  Upper middle income
# 462                    Belarus  NW.NCA.RNEW.TO  Upper middle income
# 463                    Belarus       NW.NFA.TO  Upper middle income
# 464                    Belarus       NW.NFA.PC  Upper middle income
# 465                    Belarus       NW.PCA.TO  Upper middle income
# 466                    Belarus       NW.PCA.PC  Upper middle income
# 467                    Belarus       NW.TOW.PC  Upper middle income
# 468                    Belgium       NW.HCA.TO          High income
# 469                    Belgium       NW.HCA.PC          High income
# 470                    Belgium  NW.HCA.FEMP.PC          High income
# 471                    Belgium  NW.HCA.MEMP.PC          High income
# 472                    Belgium  NW.HCA.FEMA.PC          High income
# 473                    Belgium  NW.HCA.MALE.PC          High income
# 474                    Belgium  NW.HCA.FSEM.PC          High income
# 475                    Belgium  NW.HCA.MSEM.PC          High income
# 476                    Belgium  NW.HCA.FEMP.TO          High income
# 477                    Belgium  NW.HCA.MEMP.TO          High income
# 478                    Belgium  NW.HCA.FEMA.TO          High income
# 479                    Belgium  NW.HCA.MALE.TO          High income
# 480                    Belgium  NW.HCA.FSEM.TO          High income
# 481                    Belgium  NW.HCA.MSEM.TO          High income
# 482                    Belgium       NW.NCA.TO          High income
# 483                    Belgium       NW.NCA.PC          High income
# 484                    Belgium  NW.NCA.AGRI.PC          High income
# 485                    Belgium  NW.NCA.CROL.PC          High income
# 486                    Belgium  NW.NCA.PASL.PC          High income
# 487                    Belgium  NW.NCA.FISH.PC          High income
# 488                    Belgium  NW.NCA.FECO.PC          High income
# 489                    Belgium  NW.NCA.FTIM.PC          High income
# 490                    Belgium  NW.NCA.FOSL.PC          High income
# 491                    Belgium  NW.NCA.MANG.PC          High income
# 492                    Belgium  NW.NCA.SSOI.PC          High income
# 493                    Belgium  NW.NCA.SACO.PC          High income
# 494                    Belgium  NW.NCA.SAGA.PC          High income
# 495                    Belgium  NW.NCA.MINR.PC          High income
# 496                    Belgium  NW.NCA.SAOI.PC          High income
# 497                    Belgium  NW.NCA.PRAR.PC          High income
# 498                    Belgium  NW.NCA.RNEW.PC          High income
# 499                    Belgium  NW.NCA.AGRI.TO          High income
# 500                    Belgium  NW.NCA.CROL.TO          High income
# 501                    Belgium  NW.NCA.PASL.TO          High income
# 502                    Belgium  NW.NCA.FISH.TO          High income
# 503                    Belgium  NW.NCA.FECO.TO          High income
# 504                    Belgium  NW.NCA.FTIM.TO          High income
# 505                    Belgium  NW.NCA.FOSL.TO          High income
# 506                    Belgium  NW.NCA.MANG.TO          High income
# 507                    Belgium  NW.NCA.SSOI.TO          High income
# 508                    Belgium  NW.NCA.SACO.TO          High income
# 509                    Belgium  NW.NCA.SAGA.TO          High income
# 510                    Belgium  NW.NCA.MINR.TO          High income
# 511                    Belgium  NW.NCA.SAOI.TO          High income
# 512                    Belgium  NW.NCA.PRAR.TO          High income
# 513                    Belgium  NW.NCA.RNEW.TO          High income
# 514                    Belgium       NW.NFA.TO          High income
# 515                    Belgium       NW.NFA.PC          High income
# 516                    Belgium       NW.PCA.TO          High income
# 517                    Belgium       NW.PCA.PC          High income
# 518                    Belgium       NW.TOW.TO          High income
# 519                    Belgium       NW.TOW.PC          High income
# 520                     Belize       NW.HCA.TO  Lower middle income
# 521                     Belize       NW.HCA.PC  Lower middle income
# 522                     Belize  NW.HCA.FEMP.PC  Lower middle income
# 523                     Belize  NW.HCA.MEMP.PC  Lower middle income
# 524                     Belize  NW.HCA.FEMA.PC  Lower middle income
# 525                     Belize  NW.HCA.MALE.PC  Lower middle income
# 526                     Belize  NW.HCA.FSEM.PC  Lower middle income
# 527                     Belize  NW.HCA.MSEM.PC  Lower middle income
# 528                     Belize  NW.HCA.FEMP.TO  Lower middle income
# 529                     Belize  NW.HCA.MEMP.TO  Lower middle income
# 530                     Belize  NW.HCA.FEMA.TO  Lower middle income
# 531                     Belize  NW.HCA.MALE.TO  Lower middle income
# 532                     Belize  NW.HCA.FSEM.TO  Lower middle income
# 533                     Belize  NW.HCA.MSEM.TO  Lower middle income
# 534                     Belize       NW.NCA.TO  Lower middle income
# 535                     Belize       NW.NCA.PC  Lower middle income
# 536                     Belize  NW.NCA.AGRI.PC  Lower middle income
# 537                     Belize  NW.NCA.CROL.PC  Lower middle income
# 538                     Belize  NW.NCA.PASL.PC  Lower middle income
# 539                     Belize  NW.NCA.FISH.PC  Lower middle income
# 540                     Belize  NW.NCA.FECO.PC  Lower middle income
# 541                     Belize  NW.NCA.FTIM.PC  Lower middle income
# 542                     Belize  NW.NCA.FOSL.PC  Lower middle income
# 543                     Belize  NW.NCA.MANG.PC  Lower middle income
# 544                     Belize  NW.NCA.SSOI.PC  Lower middle income
# 545                     Belize  NW.NCA.SACO.PC  Lower middle income
# 546                     Belize  NW.NCA.MINR.PC  Lower middle income
# 547                     Belize  NW.NCA.SAOI.PC  Lower middle income
# 548                     Belize  NW.NCA.PRAR.PC  Lower middle income
# 549                     Belize  NW.NCA.RNEW.PC  Lower middle income
# 550                     Belize  NW.NCA.AGRI.TO  Lower middle income
# 551                     Belize  NW.NCA.CROL.TO  Lower middle income
# 552                     Belize  NW.NCA.PASL.TO  Lower middle income
# 553                     Belize  NW.NCA.FISH.TO  Lower middle income
# 554                     Belize  NW.NCA.FECO.TO  Lower middle income
# 555                     Belize  NW.NCA.FTIM.TO  Lower middle income
# 556                     Belize  NW.NCA.FOSL.TO  Lower middle income
# 557                     Belize  NW.NCA.MANG.TO  Lower middle income
# 558                     Belize  NW.NCA.SSOI.TO  Lower middle income
# 559                     Belize  NW.NCA.SACO.TO  Lower middle income
# 560                     Belize  NW.NCA.MINR.TO  Lower middle income
# 561                     Belize  NW.NCA.SAOI.TO  Lower middle income
# 562                     Belize  NW.NCA.PRAR.TO  Lower middle income
# 563                     Belize  NW.NCA.RNEW.TO  Lower middle income
# 564                     Belize       NW.NFA.TO  Lower middle income
# 565                     Belize       NW.NFA.PC  Lower middle income
# 566                     Belize       NW.PCA.TO  Lower middle income
# 567                     Belize       NW.PCA.PC  Lower middle income
# 568                     Belize       NW.TOW.TO  Lower middle income
# 569                     Belize       NW.TOW.PC  Lower middle income
# 570                      Benin       NW.HCA.TO  Lower middle income
# 571                      Benin       NW.HCA.PC  Lower middle income
# 572                      Benin  NW.HCA.FEMP.PC  Lower middle income
# 573                      Benin  NW.HCA.MEMP.PC  Lower middle income
# 574                      Benin  NW.HCA.FEMA.PC  Lower middle income
# 575                      Benin  NW.HCA.MALE.PC  Lower middle income
# 576                      Benin  NW.HCA.FSEM.PC  Lower middle income
# 577                      Benin  NW.HCA.MSEM.PC  Lower middle income
# 578                      Benin  NW.HCA.FEMP.TO  Lower middle income
# 579                      Benin  NW.HCA.MEMP.TO  Lower middle income
# 580                      Benin  NW.HCA.FEMA.TO  Lower middle income
# 581                      Benin  NW.HCA.MALE.TO  Lower middle income
# 582                      Benin  NW.HCA.FSEM.TO  Lower middle income
# 583                      Benin  NW.HCA.MSEM.TO  Lower middle income
# 584                      Benin       NW.NCA.TO  Lower middle income
# 585                      Benin       NW.NCA.PC  Lower middle income
# 586                      Benin  NW.NCA.AGRI.PC  Lower middle income
# 587                      Benin  NW.NCA.CROL.PC  Lower middle income
# 588                      Benin  NW.NCA.PASL.PC  Lower middle income
# 589                      Benin  NW.NCA.FISH.PC  Lower middle income
# 590                      Benin  NW.NCA.FECO.PC  Lower middle income
# 591                      Benin  NW.NCA.FTIM.PC  Lower middle income
# 592                      Benin  NW.NCA.FOSL.PC  Lower middle income
# 593                      Benin  NW.NCA.MANG.PC  Lower middle income
# 594                      Benin  NW.NCA.SSOI.PC  Lower middle income
# 595                      Benin  NW.NCA.SACO.PC  Lower middle income
# 596                      Benin  NW.NCA.SAGA.PC  Lower middle income
# 597                      Benin  NW.NCA.MINR.PC  Lower middle income
# 598                      Benin  NW.NCA.SAOI.PC  Lower middle income
# 599                      Benin  NW.NCA.PRAR.PC  Lower middle income
# 600                      Benin  NW.NCA.RNEW.PC  Lower middle income
# 601                      Benin  NW.NCA.AGRI.TO  Lower middle income
# 602                      Benin  NW.NCA.CROL.TO  Lower middle income
# 603                      Benin  NW.NCA.PASL.TO  Lower middle income
# 604                      Benin  NW.NCA.FISH.TO  Lower middle income
# 605                      Benin  NW.NCA.FECO.TO  Lower middle income
# 606                      Benin  NW.NCA.FTIM.TO  Lower middle income
# 607                      Benin  NW.NCA.FOSL.TO  Lower middle income
# 608                      Benin  NW.NCA.MANG.TO  Lower middle income
# 609                      Benin  NW.NCA.SSOI.TO  Lower middle income
# 610                      Benin  NW.NCA.SACO.TO  Lower middle income
# 611                      Benin  NW.NCA.SAGA.TO  Lower middle income
# 612                      Benin  NW.NCA.MINR.TO  Lower middle income
# 613                      Benin  NW.NCA.SAOI.TO  Lower middle income
# 614                      Benin  NW.NCA.PRAR.TO  Lower middle income
# 615                      Benin  NW.NCA.RNEW.TO  Lower middle income
# 616                      Benin       NW.NFA.TO  Lower middle income
# 617                      Benin       NW.NFA.PC  Lower middle income
# 618                      Benin       NW.PCA.TO  Lower middle income
# 619                      Benin       NW.PCA.PC  Lower middle income
# 620                      Benin       NW.TOW.TO  Lower middle income
# 621                      Benin       NW.TOW.PC  Lower middle income
# 622                    Bolivia       NW.HCA.TO  Lower middle income
# 623                    Bolivia       NW.HCA.PC  Lower middle income
# 624                    Bolivia  NW.HCA.FEMP.PC  Lower middle income
# 625                    Bolivia  NW.HCA.MEMP.PC  Lower middle income
# 626                    Bolivia  NW.HCA.FEMA.PC  Lower middle income
# 627                    Bolivia  NW.HCA.MALE.PC  Lower middle income
# 628                    Bolivia  NW.HCA.FSEM.PC  Lower middle income
# 629                    Bolivia  NW.HCA.MSEM.PC  Lower middle income
# 630                    Bolivia  NW.HCA.FEMP.TO  Lower middle income
# 631                    Bolivia  NW.HCA.MEMP.TO  Lower middle income
# 632                    Bolivia  NW.HCA.FEMA.TO  Lower middle income
# 633                    Bolivia  NW.HCA.MALE.TO  Lower middle income
# 634                    Bolivia  NW.HCA.FSEM.TO  Lower middle income
# 635                    Bolivia  NW.HCA.MSEM.TO  Lower middle income
# 636                    Bolivia       NW.NCA.TO  Lower middle income
# 637                    Bolivia       NW.NCA.PC  Lower middle income
# 638                    Bolivia  NW.NCA.AGRI.PC  Lower middle income
# 639                    Bolivia  NW.NCA.CROL.PC  Lower middle income
# 640                    Bolivia  NW.NCA.PASL.PC  Lower middle income
# 641                    Bolivia  NW.NCA.FISH.PC  Lower middle income
# 642                    Bolivia  NW.NCA.FECO.PC  Lower middle income
# 643                    Bolivia  NW.NCA.FTIM.PC  Lower middle income
# 644                    Bolivia  NW.NCA.FOSL.PC  Lower middle income
# 645                    Bolivia  NW.NCA.MANG.PC  Lower middle income
# 646                    Bolivia  NW.NCA.SSOI.PC  Lower middle income
# 647                    Bolivia  NW.NCA.SACO.PC  Lower middle income
# 648                    Bolivia  NW.NCA.SAGA.PC  Lower middle income
# 649                    Bolivia  NW.NCA.MINR.PC  Lower middle income
# 650                    Bolivia  NW.NCA.SAOI.PC  Lower middle income
# 651                    Bolivia  NW.NCA.PRAR.PC  Lower middle income
# 652                    Bolivia  NW.NCA.RNEW.PC  Lower middle income
# 653                    Bolivia  NW.NCA.AGRI.TO  Lower middle income
# 654                    Bolivia  NW.NCA.CROL.TO  Lower middle income
# 655                    Bolivia  NW.NCA.PASL.TO  Lower middle income
# 656                    Bolivia  NW.NCA.FISH.TO  Lower middle income
# 657                    Bolivia  NW.NCA.FECO.TO  Lower middle income
# 658                    Bolivia  NW.NCA.FTIM.TO  Lower middle income
# 659                    Bolivia  NW.NCA.FOSL.TO  Lower middle income
# 660                    Bolivia  NW.NCA.MANG.TO  Lower middle income
# 661                    Bolivia  NW.NCA.SSOI.TO  Lower middle income
# 662                    Bolivia  NW.NCA.SACO.TO  Lower middle income
# 663                    Bolivia  NW.NCA.SAGA.TO  Lower middle income
# 664                    Bolivia  NW.NCA.MINR.TO  Lower middle income
# 665                    Bolivia  NW.NCA.SAOI.TO  Lower middle income
# 666                    Bolivia  NW.NCA.PRAR.TO  Lower middle income
# 667                    Bolivia  NW.NCA.RNEW.TO  Lower middle income
# 668                    Bolivia       NW.NFA.TO  Lower middle income
# 669                    Bolivia       NW.NFA.PC  Lower middle income
# 670                    Bolivia       NW.PCA.TO  Lower middle income
# 671                    Bolivia       NW.PCA.PC  Lower middle income
# 672                    Bolivia       NW.TOW.TO  Lower middle income
# 673                    Bolivia       NW.TOW.PC  Lower middle income
# 674     Bosnia and Herzegovina       NW.HCA.TO  Upper middle income
# ...
# 7321   Human capital, employed male (constant 2018 US$)      33200000000.00000
# 7322          Human capital, female (constant 2018 US$)      13000000000.00000
# 7323            Human capital, male (constant 2018 US$)      39400000000.00000
# 7324  Human capital, self-employed female (constant ...       2040000000.00000
# 7325  Human capital, self-employed male (constant 20...       6190000000.00000
# 7326                Natural capital (constant 2018 US$)       6670000000.00000
# 7327     Natural capital per capita (constant 2018 US$)             1460.45500
# 7328  Natural capital per capita, agricultural land ...             1361.58300
# 7329  Natural capital per capita, agricultural land:...              924.91120
# 7330  Natural capital per capita, agricultural land:...              436.67160
# 7331  Natural capital per capita, fisheries (constan...                8.10843
# 7332  Natural capital per capita, forests: ecosystem...               17.51210
# 7333  Natural capital per capita, forests: timber (c...                0.00000
# 7334  Natural capital per capita, fossil fuels (cons...                0.00000
# 7335  Natural capital per capita, mangroves (constan...                0.00000
# 7336  Natural capital per capita, nonrenewable asset...                0.00000
# 7337  Natural capital per capita, nonrenewable asset...                0.00000
# 7338  Natural capital per capita, nonrenewable asset...                0.00000
# 7339  Natural capital per capita, nonrenewable asset...                0.00000
# 7340  Natural capital per capita, protected areas (c...               73.25123
# 7341  Natural capital per capita, renewable (constan...             1460.45500
# 7342  Natural capital, agricultural land (constant 2...       6220000000.00000
# 7343  Natural capital, agricultural land: cropland (...       4230000000.00000
# 7344  Natural capital, agricultural land: pasturelan...       2000000000.00000
# 7345     Natural capital, fisheries (constant 2018 US$)         37048130.00000
# 7346  Natural capital, forests: ecosystem services (...         80014303.00000
# 7347  Natural capital, forests: timber (constant 201...                0.00000
# 7348  Natural capital, fossil fuels (constant 2018 US$)                0.00000
# 7349     Natural capital, mangroves (constant 2018 US$)                0.00000
# 7350  Natural capital, nonrenewable assets (constant...                0.00000
# 7351  Natural capital, nonrenewable assets: coal (co...                0.00000
# 7352  Natural capital, nonrenewable assets: minerals...                0.00000
# 7353  Natural capital, nonrenewable assets: oil (con...                0.00000
# 7354  Natural capital, protected areas (constant 201...        335000000.00000
# 7355     Natural capital, renewable (constant 2018 US$)       6670000000.00000
# 7356             Net foreign assets (constant 2018 US$)                0.00000
# 7357  Net foreign assets per capita (constant 2018 US$)                0.00000
# 7358               Produced capital (constant 2018 US$)      61900000000.00000
# 7359    Produced capital per capita (constant 2018 US$)            13538.76000
# 7360                   Total wealth (constant 2018 US$)     121000000000.00000
# 7361        Total wealth per capita (constant 2018 US$)            26451.36000
# 7362                  Human capital (constant 2018 US$)      78400000000.00000
# 7363       Human capital per capita (constant 2018 US$)             2749.96200
# 7364  Human capital per capita, employed female (con...             1808.72900
# 7365  Human capital per capita, employed male (const...              444.18190
# 7366  Human capital per capita, female (constant 201...             2207.78200
# 7367  Human capital per capita, male (constant 2018 ...              542.17990
# 7368  Human capital per capita, self-employed female...              399.05240
# 7369  Human capital per capita, self-employed male (...               97.99800
# 7370  Human capital, employed female (constant 2018 ...      51500000000.00000
# 7371   Human capital, employed male (constant 2018 US$)      12700000000.00000
# 7372          Human capital, female (constant 2018 US$)      62900000000.00000
# 7373            Human capital, male (constant 2018 US$)      15500000000.00000
# 7374  Human capital, self-employed female (constant ...      11400000000.00000
# 7375  Human capital, self-employed male (constant 20...       2790000000.00000
# 7376                Natural capital (constant 2018 US$)      65900000000.00000
# 7377     Natural capital per capita (constant 2018 US$)             2313.16200
# 7378  Natural capital per capita, agricultural land ...              998.06040
# 7379  Natural capital per capita, agricultural land:...              293.49070
# 7380  Natural capital per capita, agricultural land:...              704.56970
# 7381  Natural capital per capita, fisheries (constan...               26.83955
# 7382  Natural capital per capita, forests: ecosystem...               18.65993
# 7383  Natural capital per capita, forests: timber (c...               16.35649
# 7384  Natural capital per capita, fossil fuels (cons...             1192.71300
# 7385  Natural capital per capita, mangroves (constan...               47.47982
# 7386  Natural capital per capita, nonrenewable asset...             1192.71300
# 7387  Natural capital per capita, nonrenewable asset...                0.00000
# 7388  Natural capital per capita, nonrenewable asset...              200.36950
# 7389  Natural capital per capita, nonrenewable asset...                0.00000
# 7390  Natural capital per capita, nonrenewable asset...              992.34350
# 7391  Natural capital per capita, protected areas (c...               13.05258
# 7392  Natural capital per capita, renewable (constan...             1120.44900
# 7393  Natural capital, agricultural land (constant 2...      28400000000.00000
# 7394  Natural capital, agricultural land: cropland (...       8360000000.00000
# 7395  Natural capital, agricultural land: pasturelan...      20100000000.00000
# 7396     Natural capital, fisheries (constant 2018 US$)        765000000.00000
# 7397  Natural capital, forests: ecosystem services (...        532000000.00000
# 7398  Natural capital, forests: timber (constant 201...        466000000.00000
# 7399  Natural capital, fossil fuels (constant 2018 US$)      34000000000.00000
# 7400     Natural capital, mangroves (constant 2018 US$)       1350000000.00000
# 7401  Natural capital, nonrenewable assets (constant...      34000000000.00000
# 7402  Natural capital, nonrenewable assets: coal (co...                0.00000
# 7403  Natural capital, nonrenewable assets: gas (con...       5710000000.00000
# 7404  Natural capital, nonrenewable assets: minerals...                0.00000
# 7405  Natural capital, nonrenewable assets: oil (con...      28300000000.00000
# 7406  Natural capital, protected areas (constant 201...        372000000.00000
# 7407     Natural capital, renewable (constant 2018 US$)      31900000000.00000
# 7408             Net foreign assets (constant 2018 US$)      -6300000000.00000
# 7409  Net foreign assets per capita (constant 2018 US$)             -219.61200
# 7410               Produced capital (constant 2018 US$)     574000000000.00000
# 7411    Produced capital per capita (constant 2018 US$)            20153.07000
# 7412                   Total wealth (constant 2018 US$)     712000000000.00000
# 7413        Total wealth per capita (constant 2018 US$)            24996.59000
# 7414                  Human capital (constant 2018 US$)     253000000000.00000
# 7415       Human capital per capita (constant 2018 US$)            14601.85000
# 7416  Human capital per capita, employed female (con...             3573.02800
# 7417  Human capital per capita, employed male (const...             4783.58200
# 7418  Human capital per capita, female (constant 201...             6243.29900
# 7419  Human capital per capita, male (constant 2018 ...             8358.55100
# 7420  Human capital per capita, self-employed female...             2670.27100
# 7421  Human capital per capita, self-employed male (...             3574.96900
# 7422  Human capital, employed female (constant 2018 ...      62000000000.00000
# 7423   Human capital, employed male (constant 2018 US$)      83000000000.00000
# 7424          Human capital, female (constant 2018 US$)     108000000000.00000
# 7425            Human capital, male (constant 2018 US$)     145000000000.00000
# 7426  Human capital, self-employed female (constant ...      46300000000.00000
# 7427  Human capital, self-employed male (constant 20...      62000000000.00000
# 7428                Natural capital (constant 2018 US$)     139000000000.00000
# 7429     Natural capital per capita (constant 2018 US$)             8038.12400
# 7430  Natural capital per capita, agricultural land ...             1672.31200
# 7431  Natural capital per capita, agricultural land:...              762.54280
# 7432  Natural capital per capita, agricultural land:...              909.76940
# 7433  Natural capital per capita, fisheries (constan...                0.00000
# 7434  Natural capital per capita, forests: ecosystem...             1659.49000
# 7435  Natural capital per capita, forests: timber (c...             2459.75000
# 7436  Natural capital per capita, fossil fuels (cons...               14.51082
# 7437  Natural capital per capita, mangroves (constan...                0.00000
# 7438  Natural capital per capita, nonrenewable asset...              976.22160
# 7439  Natural capital per capita, nonrenewable asset...               14.51082
# 7440  Natural capital per capita, nonrenewable asset...                0.00000
# 7441  Natural capital per capita, nonrenewable asset...              961.71080
# 7442  Natural capital per capita, nonrenewable asset...                0.00000
# 7443  Natural capital per capita, protected areas (c...             1270.35100
# 7444  Natural capital per capita, renewable (constan...             7061.90300
# 7445  Natural capital, agricultural land (constant 2...      29000000000.00000
# 7446  Natural capital, agricultural land: cropland (...      13200000000.00000
# 7447  Natural capital, agricultural land: pasturelan...      15800000000.00000
# 7448     Natural capital, fisheries (constant 2018 US$)                0.00000
# 7449  Natural capital, forests: ecosystem services (...      28800000000.00000
# 7450  Natural capital, forests: timber (constant 201...      42700000000.00000
# 7451  Natural capital, fossil fuels (constant 2018 US$)        252000000.00000
# 7452     Natural capital, mangroves (constant 2018 US$)                0.00000
# 7453  Natural capital, nonrenewable assets (constant...      16900000000.00000
# 7454  Natural capital, nonrenewable assets: coal (co...        252000000.00000
# 7455  Natural capital, nonrenewable assets: gas (con...                0.00000
# 7456  Natural capital, nonrenewable assets: minerals...      16700000000.00000
# 7457  Natural capital, nonrenewable assets: oil (con...                0.00000
# 7458  Natural capital, protected areas (constant 201...      22000000000.00000
# 7459     Natural capital, renewable (constant 2018 US$)     123000000000.00000
# 7460             Net foreign assets (constant 2018 US$)     -29000000000.00000
# 7461  Net foreign assets per capita (constant 2018 US$)            -1656.38000
# 7462               Produced capital (constant 2018 US$)     124000000000.00000
# 7463    Produced capital per capita (constant 2018 US$)             7169.96400
# 7464                   Total wealth (constant 2018 US$)     489000000000.00000
# 7465        Total wealth per capita (constant 2018 US$)            28153.56000
# 7466                  Human capital (constant 2018 US$)     226000000000.00000
# 7467       Human capital per capita (constant 2018 US$)            15641.47000
# 7468  Human capital per capita, employed female (con...             4583.18700
# 7469  Human capital per capita, employed male (const...             6905.64100
# 7470  Human capital per capita, female (constant 201...             6239.78200
# 7471  Human capital per capita, male (constant 2018 ...             9401.68800
# 7472  Human capital per capita, self-employed female...             1656.59500
# 7473  Human capital per capita, self-employed male (...             2496.04700
# 7474  Human capital, employed female (constant 2018 ...      66200000000.00000
# 7475   Human capital, employed male (constant 2018 US$)      99700000000.00000
# 7476          Human capital, female (constant 2018 US$)      90100000000.00000
# 7477            Human capital, male (constant 2018 US$)     136000000000.00000
# 7478  Human capital, self-employed female (constant ...      23900000000.00000
# 7479  Human capital, self-employed male (constant 20...      36000000000.00000
# 7480                Natural capital (constant 2018 US$)      64500000000.00000
# 7481     Natural capital per capita (constant 2018 US$)             4464.66900
# 7482  Natural capital per capita, agricultural land ...             1097.72000
# 7483  Natural capital per capita, agricultural land:...              435.50290
# 7484  Natural capital per capita, agricultural land:...              662.21710
# 7485  Natural capital per capita, fisheries (constan...                0.00000
# 7486  Natural capital per capita, forests: ecosystem...             1327.80200
# 7487  Natural capital per capita, forests: timber (c...             1076.71000
# 7488  Natural capital per capita, fossil fuels (cons...              187.21850
# 7489  Natural capital per capita, mangroves (constan...                0.00000
# 7490  Natural capital per capita, nonrenewable asset...              393.40630
# 7491  Natural capital per capita, nonrenewable asset...              187.21850
# 7492  Natural capital per capita, nonrenewable asset...                0.00000
# 7493  Natural capital per capita, nonrenewable asset...              206.18770
# 7494  Natural capital per capita, nonrenewable asset...                0.00000
# 7495  Natural capital per capita, protected areas (c...              569.03180
# 7496  Natural capital per capita, renewable (constan...             4071.26300
# 7497  Natural capital, agricultural land (constant 2...      15800000000.00000
# 7498  Natural capital, agricultural land: cropland (...       6290000000.00000
# 7499  Natural capital, agricultural land: pasturelan...       9560000000.00000
# 7500     Natural capital, fisheries (constant 2018 US$)                0.00000
# 7501  Natural capital, forests: ecosystem services (...      19200000000.00000
# 7502  Natural capital, forests: timber (constant 201...      15500000000.00000
# 7503  Natural capital, fossil fuels (constant 2018 US$)       2700000000.00000
# 7504     Natural capital, mangroves (constant 2018 US$)                0.00000
# 7505  Natural capital, nonrenewable assets (constant...       5680000000.00000
# 7506  Natural capital, nonrenewable assets: coal (co...       2700000000.00000
# 7507  Natural capital, nonrenewable assets: gas (con...                0.00000
# 7508  Natural capital, nonrenewable assets: minerals...       2980000000.00000
# 7509  Natural capital, nonrenewable assets: oil (con...                0.00000
# 7510  Natural capital, protected areas (constant 201...       8220000000.00000
# 7511     Natural capital, renewable (constant 2018 US$)      58800000000.00000
# 7512             Net foreign assets (constant 2018 US$)     -13000000000.00000
# 7513  Net foreign assets per capita (constant 2018 US$)             -916.55700
# 7514               Produced capital (constant 2018 US$)      59600000000.00000
# 7515    Produced capital per capita (constant 2018 US$)             4129.25300
# 7516                   Total wealth (constant 2018 US$)     337000000000.00000
# 7517        Total wealth per capita (constant 2018 US$)            23318.84000

# %% [markdown]
# Accesing databse using sql shell
# ![image.png](attachment:image.png)
